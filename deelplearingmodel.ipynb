# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.4.0'

# %%
file1 = pd.read_csv("student-mat.csv",sep=";",header=0)
file2 = pd.read_csv("student-por.csv",sep=";",header=0)

# %%
file1['subject'] = 'Math'

# %%
file1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 subject
# 0        3     4     1     1       3        6   5   6   6    Math
# 1        3     3     1     1       3        4   5   5   6    Math
# 2        3     2     2     3       3       10   7   8  10    Math
# 3        2     2     1     1       5        2  15  14  15    Math
# 4        3     2     1     2       5        4   6  10  10    Math
#
# [5 rows x 34 columns]

# %%
file2['subject'] = 'Por'

# %%
file2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 subject
# 0        3     4     1     1       3        4   0  11  11     Por
# 1        3     3     1     1       3        2   9  11  11     Por
# 2        3     2     2     3       3        6  12  13  12     Por
# 3        2     2     1     1       5        0  14  14  14     Por
# 4        3     2     1     2       5        0  11  13  13     Por
#
# [5 rows x 34 columns]

# %%
df = pd.concat([file1,file2])

# %%
df.reset_index(drop=True,inplace=True)

# %%
 df.to_csv("student-mat-por_combinedData.csv")

# %%
 df1 = pd.read_csv('student-mat-por_combinedData.csv')

# %%
df1
# Out:
#       Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu  \
# 0              0     GP   F   18       U     GT3       A     4     4
# 1              1     GP   F   17       U     GT3       T     1     1
# 2              2     GP   F   15       U     LE3       T     1     1
# 3              3     GP   F   15       U     GT3       T     4     2
# 4              4     GP   F   16       U     GT3       T     3     3
# ...          ...    ...  ..  ...     ...     ...     ...   ...   ...
# 1039        1039     MS   F   19       R     GT3       T     2     3
# 1040        1040     MS   F   18       U     LE3       T     3     1
# 1041        1041     MS   F   18       U     GT3       T     1     1
# 1042        1042     MS   M   17       U     LE3       T     3     1
# 1043        1043     MS   M   18       R     LE3       T     3     2
#
#           Mjob  ... freetime goout Dalc  Walc  health  absences  G1  G2  G3  \
# 0      at_home  ...        3     4    1     1       3         6   5   6   6
# 1      at_home  ...        3     3    1     1       3         4   5   5   6
# 2      at_home  ...        3     2    2     3       3        10   7   8  10
# 3       health  ...        2     2    1     1       5         2  15  14  15
# 4        other  ...        3     2    1     2       5         4   6  10  10
# ...        ...  ...      ...   ...  ...   ...     ...       ...  ..  ..  ..
# 1039  services  ...        4     2    1     2       5         4  10  11  10
# 1040   teacher  ...        3     4    1     1       1         4  15  15  16
# 1041     other  ...        1     1    1     1       5         6  11  12   9
# 1042  services  ...        4     5    3     4       2         6  10  10  10
# 1043  services  ...        4     1    3     4       5         4  10  11  11
#
#      subject
# 0       Math
# 1       Math
# 2       Math
# 3       Math
# 4       Math
# ...      ...
# 1039     Por
# 1040     Por
# 1041     Por
# 1042     Por
# 1043     Por
#
# [1044 rows x 35 columns]

# %%
grade = []
for x in df["G3"]:

    if x > 15:
        grade.append(4)
    elif x >= 10:
        grade.append(3)
    elif x >= 5:
        grade.append(2)
    else:
        grade.append(1)
print(grade)
# Out:
# [2, 2, 3, 3, 3, 3, 3, 2, 4, 3, 2, 3, 3, 3, 4, 3, 3, 3, 2, 3, 3, 3, 4, 3, 2, 2, 3, 3, 3, 3, 3, 4, 4, 3, 3, 2, 4, 3, 3, 3, 3, 3, 4, 3, 2, 2, 3, 4, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 2, 2, 3, 3, 3, 2, 2, 4, 3, 3, 2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 2, 2, 3, 3, 2, 2, 4, 2, 3, 3, 3, 3, 3, 3, 2, 2, 4, 3, 2, 4, 3, 2, 4, 3, 4, 4, 3, 3, 4, 2, 4, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 2, 1, 4, 1, 1, 3, 3, 1, 1, 1, 1, 3, 3, 1, 2, 3, 3, 1, 3, 1, 3, 1, 3, 1, 3, 3, 1, 3, 2, 3, 3, 3, 3, 1, 2, 1, 3, 2, 3, 3, 4, 1, 3, 1, 4, 3, 1, 2, 2, 3, 2, 2, 3, 2, 3, 4, 2, 3, 3, 3, 3, 2, 3, 3, 2, 2, 3, 3, 3, 4, 3, 4, 3, 4, 3, 3, 2, 3, 2, 2, 3, 3, 2, 2, 3, 3, 2, 3, 3, 1, 2, 2, 3, 2, 1, 4, 3, 3, 2, 3, 3, 2, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 1, 3, 3, 1, 3, 1, 4, 3, 2, 2, 3, 2, 3, 2, 2, 3, 2, 3, 3, 3, 1, 4, 2, 3, 2, 1, 4, 3, 3, 3, 1, 2, 3, 3, 3, 3, 3, 2, 2, 2, 3, 2, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 1, 2, 3, 4, 3, 3, 3, 4, 3, 3, 4, 2, 3, 3, 1, 3, 3, 3, 3, 3, 1, 2, 3, 3, 3, 2, 3, 3, 3, 3, 4, 3, 2, 3, 2, 3, 1, 1, 1, 3, 3, 1, 4, 3, 3, 1, 3, 1, 3, 3, 4, 2, 3, 3, 2, 3, 2, 2, 3, 2, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 1, 3, 3, 2, 3, 3, 2, 4, 3, 3, 3, 3, 3, 3, 2, 3, 1, 2, 3, 2, 1, 2, 1, 2, 4, 2, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 4, 2, 3, 3, 3, 3, 4, 3, 4, 4, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 1, 3, 3, 3, 3, 2, 3, 3, 3, 1, 3, 2, 2, 3, 2, 2, 2, 3, 4, 3, 4, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 2, 4, 3, 3, 4, 3, 3, 3, 3, 2, 3, 4, 3, 3, 3, 3, 2, 2, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 2, 3, 3, 2, 3, 2, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 3, 3, 4, 3, 4, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 4, 3, 3, 4, 4, 4, 4, 3, 3, 3, 3, 4, 4, 3, 3, 2, 4, 4, 3, 3, 3, 3, 3, 3, 4, 4, 3, 4, 3, 3, 3, 3, 4, 4, 3, 3, 3, 3, 2, 3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 4, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 4, 3, 3, 3, 4, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 2, 3, 3, 3, 2, 3, 3, 3, 2, 3, 3, 4, 1, 2, 3, 2, 3, 2, 3, 2, 4, 3, 3, 3, 3, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 2, 3, 2, 3, 3, 3, 2, 3, 2, 3, 3, 3, 2, 3, 3, 2, 3, 3, 2, 3, 3, 3, 3, 4, 2, 3, 2, 3, 3, 3, 3, 3, 2, 4, 4, 3, 2, 2, 2, 3, 4, 3, 2, 1, 2, 3, 2, 2, 2, 4, 3, 3, 2, 3, 2, 3, 2, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 2, 2, 1, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3, 2, 3, 2, 2, 1, 3, 2, 1, 2, 2, 3, 2, 3, 3, 3, 4, 4, 4, 1, 3, 3, 3, 3, 3, 1, 3, 1, 4, 3, 3, 3, 1, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 2, 4, 2, 3, 1, 3, 3, 2, 4, 3, 2, 3, 4, 2, 4, 1, 4, 1, 1, 3, 3, 3, 3, 4, 2, 3, 3]

# %%
df["grade"] = grade
df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
#       ... goout Dalc  Walc  health  absences  G1  G2  G3 subject grade
# 0     ...     4    1     1       3         6   5   6   6    Math     2
# 1     ...     3    1     1       3         4   5   5   6    Math     2
# 2     ...     2    2     3       3        10   7   8  10    Math     3
# 3     ...     2    1     1       5         2  15  14  15    Math     3
# 4     ...     2    1     2       5         4   6  10  10    Math     3
# ...   ...   ...  ...   ...     ...       ...  ..  ..  ..     ...   ...
# 1039  ...     2    1     2       5         4  10  11  10     Por     3
# 1040  ...     4    1     1       1         4  15  15  16     Por     4
# 1041  ...     1    1     1       5         6  11  12   9     Por     2
# 1042  ...     5    3     4       2         6  10  10  10     Por     3
# 1043  ...     1    3     4       5         4  10  11  11     Por     3
#
# [1044 rows x 35 columns]

# %%
new_df = df.drop(columns = ["G2","G1","G3"])
new_df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
#       ... romantic famrel  freetime  goout  Dalc Walc health absences subject  \
# 0     ...       no      4         3      4     1    1      3        6    Math
# 1     ...       no      5         3      3     1    1      3        4    Math
# 2     ...       no      4         3      2     2    3      3       10    Math
# 3     ...      yes      3         2      2     1    1      5        2    Math
# 4     ...       no      4         3      2     1    2      5        4    Math
# ...   ...      ...    ...       ...    ...   ...  ...    ...      ...     ...
# 1039  ...       no      5         4      2     1    2      5        4     Por
# 1040  ...       no      4         3      4     1    1      1        4     Por
# 1041  ...       no      1         1      1     1    1      5        6     Por
# 1042  ...       no      2         4      5     3    4      2        6     Por
# 1043  ...       no      4         4      1     3    4      5        4     Por
#
#      grade
# 0        2
# 1        2
# 2        3
# 3        3
# 4        3
# ...    ...
# 1039     3
# 1040     4
# 1041     2
# 1042     3
# 1043     3
#
# [1044 rows x 32 columns]

# %%
data = new_df.values
X = new_df.drop(columns =["grade"])
y = new_df['grade']
y
# Out:
# 0       2
# 1       2
# 2       3
# 3       3
# 4       3
#        ..
# 1039    3
# 1040    4
# 1041    2
# 1042    3
# 1043    3
# Name: grade, Length: 1044, dtype: int64

# %%
cat_columns = ["school","sex","address","famsize","Pstatus","Mjob","Fjob","reason","guardian","schoolsup","famsup","paid","activities","nursery","higher","internet","romantic","subject"]
cat_columns2 = ["school","absences","age","health","Walc","goout","subject"]

cat_columns2
# Out:
# ['school', 'absences', 'age', 'health', 'Walc', 'goout', 'subject']

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
label_encoder = LabelEncoder()

# %%
X= X[cat_columns2]
##X= X.apply(LabelEncoder().fit_transform)
X
# Out:
#      school  absences  age  health  Walc  goout subject
# 0        GP         6   18       3     1      4    Math
# 1        GP         4   17       3     1      3    Math
# 2        GP        10   15       3     3      2    Math
# 3        GP         2   15       5     1      2    Math
# 4        GP         4   16       5     2      2    Math
# ...     ...       ...  ...     ...   ...    ...     ...
# 1039     MS         4   19       5     2      2     Por
# 1040     MS         4   18       1     1      4     Por
# 1041     MS         6   18       5     1      1     Por
# 1042     MS         6   17       2     4      5     Por
# 1043     MS         4   18       5     4      1     Por
#
# [1044 rows x 7 columns]

# %%
X[["school","subject"]] = X[["school","subject"]].apply(LabelEncoder().fit_transform)

# %%
print(X)
# Out:
#       school  absences  age  health  Walc  goout  subject
# 0          0         6   18       3     1      4        0
# 1          0         4   17       3     1      3        0
# 2          0        10   15       3     3      2        0
# 3          0         2   15       5     1      2        0
# 4          0         4   16       5     2      2        0
# ...      ...       ...  ...     ...   ...    ...      ...
# 1039       1         4   19       5     2      2        1
# 1040       1         4   18       1     1      4        1
# 1041       1         6   18       5     1      1        1
# 1042       1         6   17       2     4      5        1
# 1043       1         4   18       5     4      1        1
#
# [1044 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
import sklearn
from tensorflow.keras.utils import to_categorical

# %%
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=7))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=100, activation='relu'))

model.add(Dense(units=5, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               800
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 505
# =================================================================
# Total params: 21,505
# Trainable params: 21,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=190,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/190
# 25/25 - 0s - loss: 1.2317 - accuracy: 0.5913
# Epoch 2/190
# 25/25 - 0s - loss: 0.9643 - accuracy: 0.6679
# Epoch 3/190
# 25/25 - 0s - loss: 0.9014 - accuracy: 0.6718
# Epoch 4/190
# 25/25 - 0s - loss: 0.8747 - accuracy: 0.6628
# Epoch 5/190
# 25/25 - 0s - loss: 0.8499 - accuracy: 0.6718
# Epoch 6/190
# 25/25 - 0s - loss: 0.8354 - accuracy: 0.6782
# Epoch 7/190
# 25/25 - 0s - loss: 0.8176 - accuracy: 0.6794
# Epoch 8/190
# 25/25 - 0s - loss: 0.8026 - accuracy: 0.6782
# Epoch 9/190
# 25/25 - 0s - loss: 0.7895 - accuracy: 0.6871
# Epoch 10/190
# 25/25 - 0s - loss: 0.7802 - accuracy: 0.6986
# Epoch 11/190
# 25/25 - 0s - loss: 0.7722 - accuracy: 0.6935
# Epoch 12/190
# 25/25 - 0s - loss: 0.7518 - accuracy: 0.6948
# Epoch 13/190
# 25/25 - 0s - loss: 0.7415 - accuracy: 0.6973
# Epoch 14/190
# 25/25 - 0s - loss: 0.7320 - accuracy: 0.7139
# Epoch 15/190
# 25/25 - 0s - loss: 0.7180 - accuracy: 0.7063
# Epoch 16/190
# 25/25 - 0s - loss: 0.7100 - accuracy: 0.7165
# Epoch 17/190
# 25/25 - 0s - loss: 0.7285 - accuracy: 0.7126
# Epoch 18/190
# 25/25 - 0s - loss: 0.7140 - accuracy: 0.7114
# Epoch 19/190
# 25/25 - 0s - loss: 0.6908 - accuracy: 0.7165
# Epoch 20/190
# 25/25 - 0s - loss: 0.6763 - accuracy: 0.7229
# Epoch 21/190
# 25/25 - 0s - loss: 0.6808 - accuracy: 0.7101
# 25/25 - 0s - loss: 0.1406 - accuracy: 0.9336
# Epoch 169/190
# 25/25 - 0s - loss: 0.1476 - accuracy: 0.9221
# Epoch 170/190
# 25/25 - 0s - loss: 0.1533 - accuracy: 0.9272
# Epoch 171/190
# 25/25 - 0s - loss: 0.1536 - accuracy: 0.9246
# Epoch 172/190
# 25/25 - 0s - loss: 0.1409 - accuracy: 0.9310
# Epoch 173/190
# 25/25 - 0s - loss: 0.1486 - accuracy: 0.9298
# Epoch 174/190
# 25/25 - 0s - loss: 0.1470 - accuracy: 0.9310
# Epoch 175/190
# 25/25 - 0s - loss: 0.1369 - accuracy: 0.9361
# Epoch 176/190
# 25/25 - 0s - loss: 0.1487 - accuracy: 0.9310
# Epoch 177/190
# 25/25 - 0s - loss: 0.1500 - accuracy: 0.9298
# Epoch 178/190
# 25/25 - 0s - loss: 0.1370 - accuracy: 0.9400
# Epoch 179/190
# 25/25 - 0s - loss: 0.1390 - accuracy: 0.9349
# Epoch 180/190
# 25/25 - 0s - loss: 0.1354 - accuracy: 0.9323
# Epoch 181/190
# 25/25 - 0s - loss: 0.1433 - accuracy: 0.9349
# Epoch 182/190
# 25/25 - 0s - loss: 0.1425 - accuracy: 0.9298
# Epoch 183/190
# 25/25 - 0s - loss: 0.1359 - accuracy: 0.9387
# Epoch 184/190
# 25/25 - 0s - loss: 0.1698 - accuracy: 0.9157
# Epoch 185/190
# 25/25 - 0s - loss: 0.1717 - accuracy: 0.9170
# Epoch 186/190
# 25/25 - 0s - loss: 0.1467 - accuracy: 0.9272
# Epoch 187/190
# 25/25 - 0s - loss: 0.1594 - accuracy: 0.9208
# Epoch 188/190
# 25/25 - 0s - loss: 0.1493 - accuracy: 0.9298
# Epoch 189/190
# 25/25 - 0s - loss: 0.1633 - accuracy: 0.9234
# Epoch 190/190
# 25/25 - 0s - loss: 0.1331 - accuracy: 0.9361

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 9/9 - 0s - loss: 2.8872 - accuracy: 0.5364
# Normal Neural Network - Loss: 2.887235641479492, Accuracy: 0.5363984704017639

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:10])
print(encoded_predictions)
# Out:
# WARNING:tensorflow:From <ipython-input-33-534052de1c23>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# [2 4 3 3 1 3 3 4 4 3]

# %%
print(f'actual {y_test.head(10)} prediction{encoded_predictions[:10]}')
# Out:
# actual 550    2
# 78     3
# 335    3
# 708    3
# 99     2
# 622    3
# 165    3
# 94     3
# 867    4
# 702    3
# Name: grade, dtype: int64 prediction[2 4 3 3 1 3 3 4 4 3]

# %%
print(X_test_scaled)
# Out:
# [[-0.60538595  2.75073493  0.22968964 ... -0.21497738  1.58738503
#    0.77117098]
#  [-0.60538595 -0.38598021  0.22968964 ... -0.98712093 -1.85323082
#   -1.29672929]
#  [-0.60538595  1.80972039  0.22968964 ...  0.55716616  1.58738503
#   -1.29672929]
#  ...
#  [-0.60538595 -0.69965172  0.22968964 ... -0.21497738 -0.99307686
#   -1.29672929]
#  [-0.60538595 -0.0723087  -0.58043193 ...  0.55716616 -0.1329229
#    0.77117098]
#  [ 1.6518388   0.55503433 -0.58043193 ... -0.98712093  1.58738503
#    0.77117098]]

# %%
# Save the model
model.save('deeplearning.h5')
